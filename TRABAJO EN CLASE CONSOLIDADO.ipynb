# %% [markdown]
# <center><img SRC="OIP.jpg"/></center>
# <center><h1 style="color: #483D8B"> Analisis de datos</h1></center>
# <center><h2 style="color: #008B8B"> Universidad Castro Carazo</h2></center>
# <center><h6 style="color: #008B8B"> II Cuatrimestre 2022</h6></center>
# </br>
# </br>
# <p>Explicación del proyecto que se este presentando, para alinear el texto se debe de usar el text-aling:center.</p>
#
# <p>Para ingresar un link se usa: a href="htl">Nombre del link- y cierro a </p>
# <a href="https://www.w3schools.com/cssref/css_colors.asp">Pagina para Stylos </a>
# <p>Para usar negrita style="font-weight:bold" </p>
# <p style="font-weight:bold"> Prueba en negrita</p>

# %% [markdown]
# <h2 Style="color:#483D8B">1. Carga y estandarización de los archivos de datos </h2>
# <p style ="font-weight:bold"> ¿Que se en este apartado?</p>
# <ol>
#     <li> Importar las librerias a utilizar</li>
#     <li> Importar los <p style="font-wight:bold">set de datos</p>      (xlsx,csv,txt, oracle</li>
#     <li> Revisión de las columnas del set de datos</li>
#     <li> Si tenemos mas de un set, unirlo en un unico dataframe</li>
# </ol>
#
# <h5 style="color: #008B8B">1.1 Importar las librerias a utilizar</h5>

# %%
# Se coloca una explicación de que se cargaran las librerias para el analisis en curso
import pandas as pd #para los manejo de los datos -Dataframe-.
import numpy as np # Para menejo de estructuras de datos -Listas-.
import matplotlib.pyplot as plt # Para la creación de los graficos.
# Se le da correr para que cargue las librerias verificando la bolita negra.

# %% [markdown]
# <h5 style="color: #008B8B">1.2 Importar el set de datos</h5>
# <a hre="https://archive.ics.uci.edu/ml/datasets/Automobile">Fuente de datos</a>

# %%
# Importante si el set de datos no trae nombres de columnas. Se debe de crear la lista con los nombre como una variable.
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
"style", "wheels", "engine", "base", "length", "width", "heingt",
"curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
"compression", "horsepower", "peak", "City", "Higway", "price"]
#Se cargan los set de datos en la memoria del la PC
df_autos1=pd.read_csv("autos1.csv",names=cols)
df_autos2=pd.read_csv("autos.csv",names=cols)

# %% [markdown]
# <h5 style="color: #008B8B"> Revisión y Validación de las varialbles</h5>
# <center><p>Este proceso de revision permite identificar viariables o datos que deben ser analizados de manera independiente ya que no concuerdan con el rango de información a contener.</p>

# %%
df_autos1
# Out:
#     symboling normalized        make    fuel aspiration doors      style  \
# 0           0        106      nissan     gas        std  four      sedan
# 1           0        128      nissan     gas        std  four      sedan
# 2           0        108      nissan     gas        std  four      wagon
# 3           0        108      nissan     gas        std  four      sedan
# 4           3        194      nissan     gas        std   two  hatchback
# ..        ...        ...         ...     ...        ...   ...        ...
# 92          0          ?  volkswagen  diesel      turbo  four      sedan
# 93          0          ?  volkswagen     gas        std  four      wagon
# 94         -2        103       volvo     gas        std  four      sedan
# 95         -1         74       volvo     gas        std  four      wagon
# 96         -2        103       volvo     gas        std  four      sedan
#
#    wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
df_autos2
# Out:
#      symboling normalized         make    fuel aspiration doors        style  \
# 0            3          ?  alfa-romero     gas        std   two  convertible
# 1            3          ?  alfa-romero     gas        std   two  convertible
# 2            1          ?  alfa-romero     gas        std   two    hatchback
# 3            2        164         audi     gas        std  four        sedan
# 4            2        164         audi     gas        std  four        sedan
# ..         ...        ...          ...     ...        ...   ...          ...
# 192          0          ?   volkswagen  diesel      turbo  four        sedan
# 193          0          ?   volkswagen     gas        std  four        wagon
# 194         -2        103        volvo     gas        std  four        sedan
# 195         -1         74        volvo     gas        std  four        wagon
# 196         -2        103        volvo     gas        std  four        sedan
#
# ...

# %%
#Para conocer la cantidad de columnas y sus observaciones se utiliza el siguiente codigo: Siendo su primer dato cantidad de observaciones y segundo sus columnas
df_autos1.shape
# Out:
# (97, 26)

# %%
df_autos2.shape
# Out:
# (197, 26)

# %%
#Para conocer los nombres de las las columnas se utiliza
df_autos1.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_autos2.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_autos1.head(15)
# Out:
#     symboling normalized    make    fuel aspiration doors      style wheels  \
# 0           0        106  nissan     gas        std  four      sedan    fwd
# 1           0        128  nissan     gas        std  four      sedan    fwd
# 2           0        108  nissan     gas        std  four      wagon    fwd
# 3           0        108  nissan     gas        std  four      sedan    fwd
# 4           3        194  nissan     gas        std   two  hatchback    rwd
# 5           3        194  nissan     gas      turbo   two  hatchback    rwd
# 6           1        231  nissan     gas        std   two  hatchback    rwd
# 7           0        161  peugot     gas        std  four      sedan    rwd
# 8           0        161  peugot  diesel      turbo  four      sedan    rwd
# 9           0          ?  peugot     gas        std  four      wagon    rwd
# 10          0          ?  peugot  diesel      turbo  four      wagon    rwd
# ...

# %%
df_autos1.tail(15)
# Out:
#     symboling normalized        make    fuel aspiration doors        style  \
# 82          2        122  volkswagen  diesel        std   two        sedan
# 83          2        122  volkswagen     gas        std   two        sedan
# 84          2         94  volkswagen  diesel        std  four        sedan
# 85          2         94  volkswagen     gas        std  four        sedan
# 86          2         94  volkswagen     gas        std  four        sedan
# 87          2         94  volkswagen  diesel      turbo  four        sedan
# 88          2         94  volkswagen     gas        std  four        sedan
# 89          3          ?  volkswagen     gas        std   two  convertible
# 90          3        256  volkswagen     gas        std   two    hatchback
# 91          0          ?  volkswagen     gas        std  four        sedan
# 92          0          ?  volkswagen  diesel      turbo  four        sedan
# ...

# %%
df_autos1.describe()
# Out:
#        symboling        base      length      width     heingt         curb  \
# count  97.000000   97.000000   97.000000  97.000000  97.000000    97.000000
# mean    0.855670   98.823711  175.208247  65.872165  54.194845  2587.175258
# std     1.314896    5.332170   10.064062   1.655719   2.416755   412.305914
# min    -2.000000   89.500000  156.900000  63.400000  49.700000  1918.000000
# 25%     0.000000   95.700000  168.900000  64.400000  52.500000  2261.000000
# 50%     0.000000   97.300000  173.500000  65.600000  54.500000  2535.000000
# 75%     2.000000  100.400000  183.500000  66.600000  56.000000  2975.000000
# max     3.000000  114.200000  198.900000  72.300000  59.800000  3485.000000
#
#        engine-size       bore     stroke  compression       City     Higway
# count    97.000000  97.000000  97.000000    97.000000  97.000000  97.000000
# mean    125.432990   3.388969   3.169381    10.570206  25.185567  30.814433
# ...

# %%
df_autos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    97 non-null     int64
#  1   normalized   97 non-null     object
#  2   make         97 non-null     object
#  3   fuel         97 non-null     object
#  4   aspiration   97 non-null     object
#  5   doors        97 non-null     object
#  6   style        97 non-null     object
#  7   wheels       97 non-null     object
#  8   engine       97 non-null     object
#  9   base         97 non-null     float64
#  10  length       97 non-null     float64
#  11  width        97 non-null     float64
#  12  heingt       97 non-null     float64
#  13  curb         97 non-null     int64
#  14  engineType   97 non-null     object
#  15  Cylinders    97 non-null     object
#  16  engine-size  97 non-null     int64
#  17  system       97 non-null     object
# ...

# %% [markdown]
# <h5 style="color: #008B8B">1.4 Unir los ser de datos</h5>

# %%
#df_autos1-97 observaciones y 26 columnas
#df_autos2-197 observaciones y 26 columnas


Unionarchivos=[df_autos1,df_autos2]
df_autos=pd.concat(Unionarchivos)
df_autos.shape
# Out:
# (294, 26)

# %% [markdown]
# <h2 Style="color:#483D8B">2. Manejo de valores faltantes </h2>
# <p style ="font-weight:bold"> ¿Que se en este apartado?</p>
# <ol>
#     <li> Identificar como se muestran los valores faltantes y estandarizarlos a NaN</li>
#     <li> Contar la cantidad de valores NaN (Faltantes)</li>
#     <li> Analisis para imputar los valorwa numericos con la media</li>
#     <li> Analisis para imputar los caracter con el mas frecuente</li>
#     <li> Eliminar filas con valores faltantes</li>
# </ol>
#
# <h5 style="color: #008B8B">2.1 Identificar como se muestra los valores faltantes y estandarizalos a NaN</h5>

# %% [markdown]
# <p> Valores faltantes</p>
# <ol>
#     <li>NaN</li>
#     <li>" "</li>
#     <li>null</li>
#     <li>?</li>
#     <li>entre otros</li>
# </ol>

# %%
df_autos.replace("?",np.nan,inplace=True)
df_autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        NaN  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %% [markdown]
# <h5 style="color: #008B8B">Contar los valores faltantes por columna</h5>

# %%
valoresperdidos=df_autos.isnull()
valoresperdidos.head(10)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False       False  False  False       False  False  False   False
# 1      False       False  False  False       False  False  False   False
# 2      False       False  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
# 5      False       False  False  False       False  False  False   False
# 6      False       False  False  False       False  False  False   False
# 7      False       False  False  False       False  False  False   False
# 8      False       False  False  False       False  False  False   False
# 9      False        True  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# ...

# %%
for column in valoresperdidos.columns.values.tolist():
    print(column)
    print(valoresperdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    294
# Name: symboling, dtype: int64
#
# normalized
# False    237
# True      57
# Name: normalized, dtype: int64
#
# make
# False    294
# Name: make, dtype: int64
#
# fuel
# False    294
# Name: fuel, dtype: int64
#
# aspiration
# False    294
# Name: aspiration, dtype: int64
#
# doors
# False    292
# True       2
# Name: doors, dtype: int64
#
# style
# False    294
# Name: style, dtype: int64
#
# wheels
# False    294
# Name: wheels, dtype: int64
#
# engine
# False    294
# Name: engine, dtype: int64
#
# base
# False    294
# Name: base, dtype: int64
#
# length
# False    294
# Name: length, dtype: int64
#
# width
# False    294
# Name: width, dtype: int64
#
# heingt
# False    294
# Name: heingt, dtype: int64
#
# curb
# False    294
# Name: curb, dtype: int64
#
# engineType
# False    294
# Name: engineType, dtype: int64
#
# Cylinders
# False    294
# Name: Cylinders, dtype: int64
#
# engine-size
# False    294
# Name: engine-size, dtype: int64
#
# system
# ...

# %% [markdown]
# <h5 style="color: #008B8B">Analisis para imputar datos númericos con la media</h5>

# %%
avg_norm=df_autos["price"].astype("float").mean(axis=0)
print("La media es:",avg_norm)
# Out:
# La media es: 12625.910034602077

# %%
df_autos["price"].replace(np.nan,12626,inplace=True)
df_autos.head(10)
# Out:
#    symboling normalized    make    fuel aspiration doors      style wheels  \
# 0          0        106  nissan     gas        std  four      sedan    fwd
# 1          0        128  nissan     gas        std  four      sedan    fwd
# 2          0        108  nissan     gas        std  four      wagon    fwd
# 3          0        108  nissan     gas        std  four      sedan    fwd
# 4          3        194  nissan     gas        std   two  hatchback    rwd
# 5          3        194  nissan     gas      turbo   two  hatchback    rwd
# 6          1        231  nissan     gas        std   two  hatchback    rwd
# 7          0        161  peugot     gas        std  four      sedan    rwd
# 8          0        161  peugot  diesel      turbo  four      sedan    rwd
# 9          0        NaN  peugot     gas        std  four      wagon    rwd
#
#   engine   base  ...  engine-size  system  bore  stroke compression  \
# 0  front   97.2  ...          120    2bbl  3.33    3.47         8.5
# ...

# %% [markdown]
# <h5 style="color: #008B8B">Analisis para imputar caracteres más frecuentes</h5>

# %%
df_autos["doors"].value_counts()
# Out:
# four    167
# two     125
# Name: doors, dtype: int64

# %%
df_autos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
df_autos["doors"].replace(np.nan,"four",inplace=True)

# %%
valoresperdidos=df_autos.isnull()
for column in valoresperdidos.columns.values.tolist():
    print(column)
    print(valoresperdidos[column].value_counts())
    print("")
# Out:
# symboling
# False    294
# Name: symboling, dtype: int64
#
# normalized
# False    237
# True      57
# Name: normalized, dtype: int64
#
# make
# False    294
# Name: make, dtype: int64
#
# fuel
# False    294
# Name: fuel, dtype: int64
#
# aspiration
# False    294
# Name: aspiration, dtype: int64
#
# doors
# False    294
# Name: doors, dtype: int64
#
# style
# False    294
# Name: style, dtype: int64
#
# wheels
# False    294
# Name: wheels, dtype: int64
#
# engine
# False    294
# Name: engine, dtype: int64
#
# base
# False    294
# Name: base, dtype: int64
#
# length
# False    294
# Name: length, dtype: int64
#
# width
# False    294
# Name: width, dtype: int64
#
# heingt
# False    294
# Name: heingt, dtype: int64
#
# curb
# False    294
# Name: curb, dtype: int64
#
# engineType
# False    294
# Name: engineType, dtype: int64
#
# Cylinders
# False    294
# Name: Cylinders, dtype: int64
#
# engine-size
# False    294
# Name: engine-size, dtype: int64
#
# system
# False    294
# ...

# %% [markdown]
# <h5 style="color: #008B8B">Eliminar filas faltantes</h5>

# %%
# No elimar más del 5%

# %%
#df_autos.dropnan("price"),axis=0 inplace=True
df_autos
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 0            0        106      nissan     gas        std  four      sedan
# 1            0        128      nissan     gas        std  four      sedan
# 2            0        108      nissan     gas        std  four      wagon
# 3            0        108      nissan     gas        std  four      sedan
# 4            3        194      nissan     gas        std   two  hatchback
# ..         ...        ...         ...     ...        ...   ...        ...
# 192          0        NaN  volkswagen  diesel      turbo  four      sedan
# 193          0        NaN  volkswagen     gas        std  four      wagon
# 194         -2        103       volvo     gas        std  four      sedan
# 195         -1         74       volvo     gas        std  four      wagon
# 196         -2        103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
#Cunando tengo indices repetidos o salteados se debe de reiniciar los indices.
df_autos.reset_index(drop=True, inplace=True)
df_autos
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 0            0        106      nissan     gas        std  four      sedan
# 1            0        128      nissan     gas        std  four      sedan
# 2            0        108      nissan     gas        std  four      wagon
# 3            0        108      nissan     gas        std  four      sedan
# 4            3        194      nissan     gas        std   two  hatchback
# ..         ...        ...         ...     ...        ...   ...        ...
# 289          0        NaN  volkswagen  diesel      turbo  four      sedan
# 290          0        NaN  volkswagen     gas        std  four      wagon
# 291         -2        103       volvo     gas        std  four      sedan
# 292         -1         74       volvo     gas        std  four      wagon
# 293         -2        103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %% [markdown]
# <h5 style="color: #008B8B">Estandarizacion de los datos</h5>

# %% [markdown]
# <p> Que se hace en este apartado?<p/>
# <ol>
#     <li>Se verifica los datos de la variable  y ajusta, si es necesario</li>
#     <li>Se convierte los valores en funcion de su interpretación</li>
#     <li>Se normalizan los datos para que los valores distintos queden entre 1 y 0 </li>
#     <li>Binning</li>
# </ol>
#
# <h5 style="color: #008B8B">Verificacion del dominio de variables</h5>

# %%
df_autos
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 0            0        106      nissan     gas        std  four      sedan
# 1            0        128      nissan     gas        std  four      sedan
# 2            0        108      nissan     gas        std  four      wagon
# 3            0        108      nissan     gas        std  four      sedan
# 4            3        194      nissan     gas        std   two  hatchback
# ..         ...        ...         ...     ...        ...   ...        ...
# 289          0        NaN  volkswagen  diesel      turbo  four      sedan
# 290          0        NaN  volkswagen     gas        std  four      wagon
# 291         -2        103       volvo     gas        std  four      sedan
# 292         -1         74       volvo     gas        std  four      wagon
# 293         -2        103       volvo     gas        std  four      sedan
#
#     wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# ...

# %%
df_autos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
##Esti se realiza para poder estandarizar los tipos de datos del negocio, no es necesario realizarlo siempre es por el ejemplo didactico##

df_autos.dropna(subset=("horsepower"), axis=0,inplace=True)
df_autos.dropna(subset=("normalized"), axis=0,inplace=True)
df_autos.reset_index(drop=True, inplace=True)
##_______________________________________________________##
df_autos[['bore','stroke','peak']]=df_autos[['bore','stroke','peak']].astype('float')
df_autos[['price']]=df_autos[['price']].astype('float')
df_autos[['normalized','horsepower']]=df_autos[['normalized','horsepower']].astype('int')
df_autos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower       int32
# peak           float64
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h5 style="color: #008B8B">Estandarizacion valores</h5>

# %%
df_autos.head(3)
# Out:
#    symboling  normalized    make fuel aspiration doors  style wheels engine  \
# 0          0         106  nissan  gas        std  four  sedan    fwd  front
# 1          0         128  nissan  gas        std  four  sedan    fwd  front
# 2          0         108  nissan  gas        std  four  wagon    fwd  front
#
#     base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0   97.2  ...          120    2bbl  3.33    3.47         8.5         97
# 1  100.4  ...          181    mpfi  3.43    3.27         9.0        152
# 2  100.4  ...          181    mpfi  3.43    3.27         9.0        152
#
#      peak City  Higway    price
# 0  5200.0   27      34   9549.0
# 1  5200.0   17      22  13499.0
# 2  5200.0   17      22  14399.0
#
# [3 rows x 26 columns]

# %%
df_autos["city-L/100km"]=235/df_autos["City"]
df_autos["higway-L/100km"]=235/df_autos["Higway"]

# %%
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  bore  stroke  compression  horsepower    peak City  \
# 0  front   97.2  ...  3.33    3.47          8.5          97  5200.0   27
# 1  front  100.4  ...  3.43    3.27          9.0         152  5200.0   17
# 2  front  100.4  ...  3.43    3.27          9.0         152  5200.0   17
# 3  front  100.4  ...  3.43    3.27          9.0         152  5200.0   19
# 4  front   91.3  ...  3.43    3.27          9.0         160  5200.0   19
#
#    Higway    price  city-L/100km  higway-L/100km
# ...

# %% [markdown]
# <h5 style="color: #008B8B">Normalizacion de valores</h5>

# %%
dfTemp=df_autos[["length","width","heingt"]]
dfTemp
# Out:
#      length  width  heingt
# 0     173.4   65.2    54.7
# 1     181.7   66.5    55.1
# 2     184.6   66.5    56.1
# 3     184.6   66.5    55.1
# 4     170.7   67.9    49.7
# ..      ...    ...     ...
# 232   171.7   65.5    55.7
# 233   165.7   64.0    51.4
# 234   188.8   67.2    56.2
# 235   188.8   67.2    57.5
# 236   188.8   67.2    56.2
#
# [237 rows x 3 columns]

# %%
df_autos["length"]=df_autos["length"]/df_autos["length"].max()
df_autos["width"]=df_autos["width"]/df_autos["width"].max()
df_autos["heingt"]=df_autos["heingt"]/df_autos["heingt"].max()
dfTemp=df_autos[["length","width","heingt"]]
dfTemp
# Out:
#        length     width    heingt
# 0    0.855874  0.909344  0.914716
# 1    0.896841  0.927476  0.921405
# 2    0.911155  0.927476  0.938127
# 3    0.911155  0.927476  0.921405
# 4    0.842547  0.947001  0.831104
# ..        ...       ...       ...
# 232  0.847483  0.913529  0.931438
# 233  0.817868  0.892608  0.859532
# 234  0.931885  0.937238  0.939799
# 235  0.931885  0.937238  0.961538
# 236  0.931885  0.937238  0.939799
#
# [237 rows x 3 columns]

# %% [markdown]
# <h5 style="color: #008B8B">Binning</h5>

# %%
df_autos
df_autos.dtypes
# Out:
# symboling           int64
# normalized          int32
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engine-size         int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower          int32
# peak              float64
# City                int64
# Higway              int64
# price             float64
# city-L/100km      float64
# higway-L/100km    float64
# dtype: object

# %%
df_autos[["horsepower"]]=df_autos[["horsepower"]].astype('int')

# %%
df_autos.dtypes
# Out:
# symboling           int64
# normalized          int32
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engine-size         int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower          int32
# peak              float64
# City                int64
# Higway              int64
# price             float64
# city-L/100km      float64
# higway-L/100km    float64
# dtype: object

# %%
bins=np.linspace(min(df_autos["horsepower"]),max(df_autos["horsepower"]),4)
bins
# Out:
# array([ 48.        ,  98.66666667, 149.33333333, 200.        ])

# %%
nombre=["pequeño","mediano","grande"]
df_autos["horsepower-bins"]=pd.cut(df_autos["horsepower"],bins,labels=nombre,include_lowest=True)

# %%
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price city-L/100km  higway-L/100km  horsepower-bins
# ...

# %%
df_autos[["horsepower","horsepower-bins"]].head(10)
# Out:
#    horsepower horsepower-bins
# 0          97         pequeño
# 1         152          grande
# 2         152          grande
# 3         152          grande
# 4         160          grande
# 5         200          grande
# 6         160          grande
# 7          97         pequeño
# 8          95         pequeño
# 9          95         pequeño

# %%
df_autos[["horsepower-bins"]].value_counts()
# Out:
# horsepower-bins
# pequeño            145
# mediano             68
# grande              24
# dtype: int64

# %%
df_autos.shape
# Out:
# (237, 29)

# %%
plt.hist(df_autos["horsepower-bins"])
plt.xlabel("Categorias")
plt.ylabel("Cantidad de autos")
plt.title("Cantidad de autos segun caballos de fuerza")
plt.show()

# %%
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price city-L/100km  higway-L/100km  horsepower-bins
# ...

# %%
# Agregar las observaciones segun marca de vehiculo
gf1=df_autos.groupby(["make"]).count()
gf1
# Out:
#                symboling  normalized  fuel  aspiration  doors  style  wheels  \
# make
# audi                   4           4     4           4      4      4       4
# bmw                    4           4     4           4      4      4       4
# chevrolet              3           3     3           3      3      3       3
# dodge                  9           9     9           9      9      9       9
# honda                 13          13    13          13     13     13      13
# jaguar                 1           1     1           1      1      1       1
# mazda                 15          15    15          15     15     15      15
# mercedes-benz          5           5     5           5      5      5       5
# mitsubishi            10          10    10          10     10     10      10
# nissan                25          25    25          25     25     25      25
# peugot                14          14    14          14     14     14      14
# ...

# %%
gf1.iloc[0:3,0:4]
# Out:
#            symboling  normalized  fuel  aspiration
# make
# audi               4           4     4           4
# bmw                4           4     4           4
# chevrolet          3           3     3           3

# %%
gf1
# Out:
#                symboling  normalized  fuel  aspiration  doors  style  wheels  \
# make
# audi                   4           4     4           4      4      4       4
# bmw                    4           4     4           4      4      4       4
# chevrolet              3           3     3           3      3      3       3
# dodge                  9           9     9           9      9      9       9
# honda                 13          13    13          13     13     13      13
# jaguar                 1           1     1           1      1      1       1
# mazda                 15          15    15          15     15     15      15
# mercedes-benz          5           5     5           5      5      5       5
# mitsubishi            10          10    10          10     10     10      10
# nissan                25          25    25          25     25     25      25
# peugot                14          14    14          14     14     14      14
# ...

# %%
gf1=gf1.loc[:,'symboling']
gf1
# Out:
# make
# audi              4
# bmw               4
# chevrolet         3
# dodge             9
# honda            13
# jaguar            1
# mazda            15
# mercedes-benz     5
# mitsubishi       10
# nissan           25
# peugot           14
# plymouth         12
# porsche           2
# saab             12
# subaru           24
# toyota           62
# volkswagen       16
# volvo             6
# Name: symboling, dtype: int64

# %%
gf1=df_autos.groupby(["make"]).count()
gf1=gf1.iloc[:,:1]
gf1=gf1.rename(columns={'make':'marca','symboling':'cantidad'})
gf1
# Out:
#                cantidad
# make
# audi                  4
# bmw                   4
# chevrolet             3
# dodge                 9
# honda                13
# jaguar                1
# mazda                15
# mercedes-benz         5
# mitsubishi           10
# nissan               25
# peugot               14
# plymouth             12
# porsche               2
# saab                 12
# subaru               24
# toyota               62
# volkswagen           16
# volvo                 6

# %%
marcas = ("audi", "bmw","chevrolet", "dodge", "honda", "jaguar", "mazda", "mercedes-benz", "mitsubishi", "nissan", 
          "peugot", "plymounth", "porshe", "saab", "subaru", "toyota", "volkswagen", "volvo")

eje_y = gf1['cantidad'].tolist()

plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.arange(len(marcas))

ax.barh(y_pos, eje_y, align='center',height=0.8, color= "#006400", alpha=1)

ax.set_yticks(y_pos, labels=marcas)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Cantidad de Vehiculos').set_color("#006400")
ax.set_title('¿Cual es la marca con mayor representación en el invetario?')

plt.show()

# %%
gf2 = df_autos.groupby(['horsepower-bins']).count()
gf2 = gf2.iloc[:,:1]
gf2
# Out:
#                  symboling
# horsepower-bins
# pequeño                145
# mediano                 68
# grande                  24

# %%
marcas = ("Pequeno", "Mediano","Grande")

eje_y = gf2['symboling'].tolist()

#Creamos la grafica
plt.bar(marcas, eje_y)

#Leyenda del eje y
plt.ylabel("Cantidad de Vehiculos")

##Leyenda en el eje x
plt.xlabel("Marca de Vehiculos")

##Titulo del Grafico
plt.title('¿Cual es la marca con mayor representación en el invetario?')

plt.show()

# %% [markdown]
# <p>Practica</p>

# %%
gfpractica=df_autos.groupby(['style']).count()
gfpractica=gfpractica.iloc[:,:1]
gfpractica
# Out:
#              symboling
# style
# convertible          3
# hardtop              8
# hatchback           88
# sedan              113
# wagon               25

# %%
eje_x = gfpractica.index.tolist()
eje_y = gfpractica['symboling'].tolist()
plt.bar(eje_x, eje_y)
plt.ylabel("Total de Vehiculos")
plt.xlabel("Modalidad de vehiculo")
plt.title('Cantidad por modalidad')

plt.show()

# %%
df_autos.head(5)
# Out:
#    symboling  normalized    make fuel aspiration doors      style wheels  \
# 0          0         106  nissan  gas        std  four      sedan    fwd
# 1          0         128  nissan  gas        std  four      sedan    fwd
# 2          0         108  nissan  gas        std  four      wagon    fwd
# 3          0         108  nissan  gas        std  four      sedan    fwd
# 4          3         194  nissan  gas        std   two  hatchback    rwd
#
#   engine   base  ...  stroke  compression  horsepower    peak City Higway  \
# 0  front   97.2  ...    3.47          8.5          97  5200.0   27     34
# 1  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 2  front  100.4  ...    3.27          9.0         152  5200.0   17     22
# 3  front  100.4  ...    3.27          9.0         152  5200.0   19     25
# 4  front   91.3  ...    3.27          9.0         160  5200.0   19     25
#
#      price city-L/100km  higway-L/100km  horsepower-bins
# ...

# %%
gf4=df_autos.groupby(['doors']).count()
gf4=gf4.iloc[:,:1]
gf4
# Out:
#        symboling
# doors
# four         140
# two           97

# %%
etiquetas=gf4.index.tolist()
sizes=gf4["symboling"].tolist()
separacion= (0,0.1)

fig1,axl=plt.subplots()
axl.pie(sizes,explode=separacion, labels=etiquetas,autopct="%1.1f%%",shadow=True,startangle=90)
axl.axis('equal')
plt.show()

# %%
gf5=df_autos.groupby(['style']).count()
gf5=gf5.iloc[:,:1]
gf5
# Out:
#              symboling
# style
# convertible          3
# hardtop              8
# hatchback           88
# sedan              113
# wagon               25

# %%
fig, ax = plt.subplots(figsize=(9, 3), subplot_kw=dict(aspect="equal"))
 
data = gf5['symboling'].tolist()
estilo = gf5.index.tolist()
 
def func(pct, allvals):
    absolute = int(np.round(pct/100.*np.sum(allvals)))
    return "{:.1f}%".format(pct, absolute)
 

wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),textprops=dict(color="w"))
 
ax.legend(wedges, estilo,
          title="Estilos",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))
 
plt.setp(autotexts, size=5, weight="bold")
 
ax.set_title("Porcentaje de vehiculos segun estilo")
 
plt.show()

# %%
# Colores del grafico: FFB85F FF7A5A 00AAA0 8ED2C9 FCF4D9
colores = ['#FFB85F', '#FF7A5A', '#00AAA0', '#8ED2C9', '#FCF4D9']
#Separaciones
separacion = (0.07,0.07,0.07,0.07,0.07)
#Creacion graficca circular
plt.pie(data, explode=separacion, labels=estilo, autopct='%1.1f%%',pctdistance=0.85, colors=colores)
 
#Dibujar Circulo Blanco
circulo = plt.Circle((0,0), 0.75, fc='white')
fig = plt.gcf()
fig.gca().add_artist(circulo)
 
plt.title("Porcentaje de vehiculos segun estilo")
 
plt.show()

# %%
import matplotlib.cbook as cbook
 
fig, ax = plt.subplots()
ax.scatter(df_autos['price'], df_autos['city-L/100km'],s=df_autos['horsepower'], alpha=0.5)
#ax.scatter(df_Autos['price'], df_Autos['horsepower-bins'],alpha=0.5)
ax.set_xlabel("Precio", fontsize=15)
ax.set_ylabel("Consumo Combustible en Ciudad", fontsize=15)
ax.set_title('Correlacion Precio vrs Consumo de Combustible en Ciudad')
 
ax.grid(True)
fig.tight_layout()
 
plt.show()
